# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
device = "cuda" # the device to load the model onto

# %%
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
#     570     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     571     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     572 )
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:3706, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3697     if dtype_orig is not None:
#    3698         torch.set_default_dtype(dtype_orig)
#    3699     (
#    3700         model,
#    3701         missing_keys,
#    3702         unexpected_keys,
#    3703         mismatched_keys,
#    3704         offload_index,
#    3705         error_msgs,
# -> 3706     ) = cls._load_pretrained_model(
#    3707         model,
#    3708         state_dict,
#    3709         loaded_state_dict_keys,  # XXX: rename?
#    3710         resolved_archive_file,
#    3711         pretrained_model_name_or_path,
#    3712         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3713         sharded_metadata=sharded_metadata,
#    3714         _fast_init=_fast_init,
#    3715         low_cpu_mem_usage=low_cpu_mem_usage,
#    3716         device_map=device_map,
#    3717         offload_folder=offload_folder,
#    3718         offload_state_dict=offload_state_dict,
#    3719         dtype=torch_dtype,
#    3720         is_quantized=(getattr(model, "quantization_method", None) == QuantizationMethod.BITS_AND_BYTES),
#    3721         keep_in_fp32_modules=keep_in_fp32_modules,
#    3722     )
#    3724 model.is_loaded_in_4bit = load_in_4bit
#    3725 model.is_loaded_in_8bit = load_in_8bit
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:4134, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, is_quantized, keep_in_fp32_modules)
#    4132         error_msgs += new_error_msgs
#    4133 else:
# -> 4134     error_msgs += _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#    4136 # force memory release
#    4137 del state_dict
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:606, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#     603         if child is not None:
#     604             load(child, state_dict, prefix + name + ".")
# --> 606 load(model_to_load, state_dict, prefix=start_prefix)
#     607 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     608 # it's safe to delete it.
#     609 del state_dict
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:604, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     602 for name, child in module._modules.items():
#     603     if child is not None:
# --> 604         load(child, state_dict, prefix + name + ".")
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:604, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     602 for name, child in module._modules.items():
#     603     if child is not None:
# --> 604         load(child, state_dict, prefix + name + ".")
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 604 (2 times)]
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:604, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     602 for name, child in module._modules.items():
#     603     if child is not None:
# --> 604         load(child, state_dict, prefix + name + ".")
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:600, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     598                     module._load_from_state_dict(*args)
#     599     else:
# --> 600         module._load_from_state_dict(*args)
#     602 for name, child in module._modules.items():
#     603     if child is not None:
#
# File ~/mistralai-Mistral-7B-Instruct-v0.2/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:2040, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2038                 setattr(self, name, input_param)
#    2039         else:
# -> 2040             param.copy_(input_param)
#    2041 except Exception as ex:
#    2042     error_msgs.append(f'While copying the parameter named "{key}", '
#    2043                       f'whose dimensions in the model are {param.size()} and '
#    2044                       f'whose dimensions in the checkpoint are {input_param.size()}, '
#    2045                       f'an exception occurred : {ex.args}.'
#    2046                       )
#
# KeyboardInterrupt:
